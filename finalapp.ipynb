# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import numpy as np

# Set page configuration
st.set_page_config(
    page_title="Hospital Patient Analytics",
    page_icon="🏥",
    layout="wide"
)

# Load and cache data
@st.cache_data
def load_data():
    df = pd.read_csv('patients.csv')
    # Calculate length of stay
    df['arrival_date'] = pd.to_datetime(df['arrival_date'])
    df['departure_date'] = pd.to_datetime(df['departure_date'])
    df['length_of_stay'] = (df['departure_date'] - df['arrival_date']).dt.days
    return df

# Load data
df = load_data()

# Title and description
st.title("🏥 Hospital Patient Analytics Dashboard")
st.markdown("""
This dashboard provides insights into patient satisfaction, service utilization, 
and hospital performance metrics.
""")

# Sidebar for filters
st.sidebar.header("🔍 Filter Data")

# Filter 1: Service type multi-select
services = st.sidebar.multiselect(
    "Select Service Types:",
    options=df['service'].unique(),
    default=df['service'].unique()
)

# Filter 2: Age range slider
age_range = st.sidebar.slider(
    "Select Age Range:",
    min_value=int(df['age'].min()),
    max_value=int(df['age'].max()),
    value=(int(df['age'].min()), int(df['age'].max()))
)

# Filter 3: Satisfaction score input
min_satisfaction = st.sidebar.number_input(
    "Minimum Satisfaction Score:",
    min_value=0,
    max_value=100,
    value=0
)

# Apply filters
filtered_df = df[
    (df['service'].isin(services)) &
    (df['age'] >= age_range[0]) &
    (df['age'] <= age_range[1]) &
    (df['satisfaction'] >= min_satisfaction)
]

# Display dataset info
st.sidebar.markdown(f"**Filtered Records:** {len(filtered_df)}")
st.sidebar.markdown(f"**Total Records:** {len(df)}")

# Main content area
tab1, tab2, tab3, tab4 = st.tabs(["📊 Overview", "📈 Service Analysis", "👥 Patient Demographics", "🔍 Detailed Data"])

with tab1:
    st.header("Overview Dashboard")
    
    # Key metrics
    col1, col2, col3, col4 = st.columns(4)
    
    with col1:
        avg_satisfaction = filtered_df['satisfaction'].mean()
        st.metric("Average Satisfaction", f"{avg_satisfaction:.1f}")
    
    with col2:
        avg_stay = filtered_df['length_of_stay'].mean()
        st.metric("Average Stay (days)", f"{avg_stay:.1f}")
    
    with col3:
        total_patients = len(filtered_df)
        st.metric("Total Patients", total_patients)
    
    with col4:
        most_common_service = filtered_df['service'].mode()[0]
        st.metric("Most Common Service", most_common_service)
    
    # Query 1: Service type vs satisfaction
    st.subheader("Query 1: How does patient satisfaction vary by service type?")
    
    fig1, ax1 = plt.subplots(figsize=(10, 6))
    service_satisfaction = filtered_df.groupby('service')['satisfaction'].mean().sort_values(ascending=False)
    
    bars = ax1.bar(service_satisfaction.index, service_satisfaction.values, 
                  color=['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4'])
    ax1.set_xlabel('Service Type')
    ax1.set_ylabel('Average Satisfaction Score')
    ax1.set_title('Average Patient Satisfaction by Service Type')
    ax1.tick_params(axis='x', rotation=45)
    
    # Add value labels on bars
    for bar in bars:
        height = bar.get_height()
        ax1.text(bar.get_x() + bar.get_width()/2., height,
                f'{height:.1f}', ha='center', va='bottom')
    
    st.pyplot(fig1)
    
    # Insights
    st.info(f"""
    **Insight:** {service_satisfaction.index[0]} has the highest average satisfaction score 
    ({service_satisfaction.values[0]:.1f}), while {service_satisfaction.index[-1]} has the lowest 
    ({service_satisfaction.values[-1]:.1f}).
    """)

with tab2:
    st.header("Service Analysis")
    
    # Query 2: Length of stay vs satisfaction correlation
    st.subheader("Query 2: Is there a relationship between length of stay and patient satisfaction?")
    
    fig2, ax2 = plt.subplots(figsize=(10, 6))
    scatter = ax2.scatter(filtered_df['length_of_stay'], filtered_df['satisfaction'], 
                        alpha=0.6, c=filtered_df['satisfaction'], cmap='viridis')
    ax2.set_xlabel('Length of Stay (days)')
    ax2.set_ylabel('Satisfaction Score')
    ax2.set_title('Length of Stay vs Patient Satisfaction')
    plt.colorbar(scatter, ax=ax2, label='Satisfaction Score')
    
    st.pyplot(fig2)
    
    # Calculate correlation
    correlation = filtered_df['length_of_stay'].corr(filtered_df['satisfaction'])
    st.metric("Correlation Coefficient", f"{correlation:.3f}")
    
    if correlation > 0:
        st.success("Positive correlation: Longer stays tend to have higher satisfaction scores.")
    elif correlation < 0:
        st.warning("Negative correlation: Longer stays tend to have lower satisfaction scores.")
    else:
        st.info("No clear correlation between length of stay and satisfaction.")

with tab3:
    st.header("Patient Demographics")
    
    # Age distribution histogram
    st.subheader("Age Distribution of Patients")
    
    fig3, ax3 = plt.subplots(figsize=(10, 6))
    ax3.hist(filtered_df['age'], bins=20, color='#4ECDC4', edgecolor='black', alpha=0.7)
    ax3.set_xlabel('Age')
    ax3.set_ylabel('Number of Patients')
    ax3.set_title('Age Distribution of Patients')
    ax3.grid(True, alpha=0.3)
    
    st.pyplot(fig3)
    
    # Age groups analysis
    st.subheader("Satisfaction by Age Groups")
    
    # Create age groups
    filtered_df['age_group'] = pd.cut(filtered_df['age'], 
                                    bins=[0, 18, 35, 50, 65, 100],
                                    labels=['0-18', '19-35', '36-50', '51-65', '65+'])
    
    age_group_satisfaction = filtered_df.groupby('age_group')['satisfaction'].mean()
    
    fig4, ax4 = plt.subplots(figsize=(10, 6))
    age_group_satisfaction.plot(kind='line', marker='o', ax=ax4, color='#FF6B6B', linewidth=2)
    ax4.set_xlabel('Age Group')
    ax4.set_ylabel('Average Satisfaction Score')
    ax4.set_title('Average Satisfaction by Age Group')
    ax4.grid(True, alpha=0.3)
    
    st.pyplot(fig4)

with tab4:
    st.header("Detailed Patient Data")
    
    # Search functionality
    search_term = st.text_input("Search patients by name:")
    
    if search_term:
        search_df = filtered_df[filtered_df['name'].str.contains(search_term, case=False, na=False)]
    else:
        search_df = filtered_df
    
    # Display data table
    st.dataframe(
        search_df[['patient_id', 'name', 'age', 'service', 'length_of_stay', 'satisfaction']],
        use_container_width=True
    )
    
    # Download filtered data
    csv = search_df.to_csv(index=False)
    st.download_button(
        label="Download Filtered Data as CSV",
        data=csv,
        file_name="filtered_patient_data.csv",
        mime="text/csv"
    )

# Footer
st.markdown("---")
st.markdown("### 📊 Data Summary")
col1, col2 = st.columns(2)

with col1:
    st.write("**Service Distribution:**")
    service_counts = filtered_df['service'].value_counts()
    st.write(service_counts)

with col2:
    st.write("**Satisfaction Statistics:**")
    st.write(filtered_df['satisfaction'].describe())
# Out:
# 2025-10-20 22:34:48.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.232 No runtime found, using MemoryCacheStorageManager
# 2025-10-20 22:34:48.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.314 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.335 Session state does not function when running a script without `streamlit run`
# 2025-10-20 22:34:48.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.351 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.363 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.367 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.368 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.369 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.369 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.371 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.953 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:48.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:49.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# C:\Users\85215\AppData\Local\Temp\ipykernel_16304\2189043104.py:176: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_group_satisfaction = filtered_df.groupby('age_group')['satisfaction'].mean()
# 2025-10-20 22:34:50.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.725 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-10-20 22:34:50.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 22:34:50.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
